# %%
import serial
ports = serial.ports.tools.list_ports.comports()
for p in ports:
    print(p.device, p.description, p.hwid)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import serial
# ----> 2 ports = serial.ports.tools.list_ports.comports()
#       3 for p in ports:
#       4     print(p.device, p.description, p.hwid)
#
# AttributeError: module 'serial' has no attribute 'ports'
